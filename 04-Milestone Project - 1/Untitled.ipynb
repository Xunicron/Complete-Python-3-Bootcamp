# %%
def display(row1,row2,row3):
    print(row1)
    print(row2)
    print(row3)

# %%
row1 = [' ',' ',' ']
row2 = [' ',' ',' ']
row3 = [' ',' ',' ']

# %%
display(row1,row2,row3)
# Out:
# [' ', ' ', ' ']
# [' ', 'X', ' ']
# [' ', ' ', ' ']

# %%
row2[1]='X'
