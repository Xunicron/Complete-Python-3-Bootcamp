# %%
coor1 = (3,2)
coor2 = (8,10)

# %%
coordinate1[1]
# Out:
# 2

# %%
4**0.5
# Out:
# 2.0

# %%
distance = (abs(coor1[1]-coor1[0])**0.5) + (abs(coor2[1]-coor2[0])**0.5)

# %%
distance
# Out:
# 2.414213562373095

# %%
(coor1[0]-coor1[1])**0.5
# Out:
# 1.0

# %%
(coor2[0]-coor2[1])**0.5
# Out:
# (8.659560562354934e-17+1.4142135623730951j)

# %%
abs(-1)
# Out:
# 1
