# %%
mylist = [1,2,3]

# %%
len(mylist)
# Out:
# 3

# %%
class Sample():
    pass

# %%
mysample = Sample()

# %%
print(mysample)

# %%
print(mylist)
# Out:
# [1, 2, 3]

# %%
class Book():
    
    def __init__(self,title,author,pages):
        
        self.title = title
        self.author = author
        self.pages = pages
        
    def __str__(self):
        return f'{self.title} by {self.author}'
    
    
    def __len__(self):
        return self.pages
    
    def __del__(self):
        print('Deleted!')

# %%
b = Book('P','R',200)

# %%
print(b)
# Out:
# P by R

# %%
str(b)
# Out:
# 'P by R'

# %%
len(b)
# Out:
# 200

# %%
del b
# Out:
# Deleted!
