# %% [markdown]
# ## Numbers

# %%
bin(10)
# Out:
# '0b1010'

# %%
hex(256)
# Out:
# '0x100'

# %%
hex(512)
# Out:
# '0x200'

# %%
hex(15)
# Out:
# '0xf'

# %%
hex(16)
# Out:
# '0x10'

# %%
hex(10)
# Out:
# '0xa'

# %%
bin(12)
# Out:
# '0b1100'

# %%
2**4
# Out:
# 16

# %%
pow(2,4)
# Out:
# 16

# %%
pow(2,4,3)
# Out:
# 1

# %%
abs(-3)
# Out:
# 3

# %%
round(3.1)
# Out:
# 3

# %%
round(3.212,1)
# Out:
# 3.2

# %%
round(3.9)
# Out:
# 4

# %% [markdown]
# ## Strings

# %%
s = 'hello world'

# %%
s.capitalize()
# Out:
# 'Hello world'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s.lower()
# Out:
# 'hello world'

# %%
s.count('o')
# Out:
# 2

# %%
s.find('o')
# Out:
# 4

# %%
s
# Out:
# 'hello world'

# %%
s.center(20,'-')
# Out:
# '----hello world-----'

# %%
print('hello\thi')
# Out:
# hello	hi

# %%
'hello\thi'.expandtabs()
# Out:
# 'hello   hi'

# %%
s.isalnum()
# Out:
# False

# %%
s = 'hello'

# %%
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True

# %%
s.islower()
# Out:
# True

# %%
s.istitle()
# Out:
# False

# %%
s.isupper()
# Out:
# False

# %%
'HELLO'.isupper()
# Out:
# True

# %%
s.split('e')
# Out:
# ['h', 'llo']

# %%
s.partition('l')
# Out:
# ('he', 'l', 'lo')

# %% [markdown]
# ## Sets

# %%
s = set()

# %%
s.add(1)

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
s = {1,2,3}

# %%
sc = s.copy()

# %%
sc
# Out:
# {1, 2, 3}

# %%
s.add(4)

# %%
sc
# Out:
# {1, 2, 3}

# %%
s.difference(sc)
# Out:
# {4}

# %%
s1 = {1,2,3}

# %%
s2 = {1,4,5}

# %%
s1.difference_update(s2)

# %%
s1
# Out:
# {2, 3}

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
s.discard(2)

# %%
s
# Out:
# {1, 3, 4}

# %%
s1 = {1,2,3}

# %%
s2 = {1,2,4}

# %%
s1.intersection(s2)
# Out:
# {1, 2}

# %%
s1.intersection_update(s2)

# %%
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {1, 2, 4}

# %%
s1 = {1,2}
s2 = {1,2,4}
s3 = {5}

# %%
s1.isdisjoint(s2)
# Out:
# False

# %%
s1.isdisjoint(s3)
# Out:
# True

# %%
s1.issubset(s2)
# Out:
# True

# %%
s2.issuperset(s1)
# Out:
# True

# %%
s1.symmetric_difference(s2)
# Out:
# {4}

# %%
s1.union(s2)
# Out:
# {1, 2, 4}

# %%
s1.update(s3)

# %%
s1
# Out:
# {1, 2, 5}

# %% [markdown]
# ## Dictionaries
