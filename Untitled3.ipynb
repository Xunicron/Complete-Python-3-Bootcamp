# %%
pos_index = int(input("A number: "))
# Out:
# A number: 2

# %%
def user_choice():
    
    choice = input("A number (0-10): ")
    
    return int(choice)

# %%
user_choice()
# Out:
# A number (0-10): 100
# 100

# %%
def user_choice():
    
    choice = 'wrong'
    acceptable_range = range(0,10)
    within_range = False
    
    while choice.isdigit() == False or within_range == False:
    
        choice = input("A number (0-10): ")
        
        if choice.isdigit() == False:
            print("Sorry?")
    
        if choice.isdigit() == True:
            if int(choice) in acceptable_range:
                within_range = True
            else:
                within_range = False
                print("Sorry out of range")

                
    
    return int(choice)

# %%
user_choice()
# Out:
# A number (0-10): 100
# Sorry out of range
# A number (0-10): kjfd
# Sorry?
# A number (0-10): 10
# Sorry out of range
# A number (0-10): 9
# 9

# %%
result = 'Wrong value'

# %%
acceptable_values = [0,1,2]

# %%
result in acceptable_values
# Out:
# False

# %%
result not in acceptable_values
# Out:
# True
