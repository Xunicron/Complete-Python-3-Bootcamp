# %%
str(1)
# Out:
# '1'

# %%
num = list(range(1,10))

# %%
num
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
5%3
# Out:
# 2

# %%
num.count(1)
# Out:
# 1

# %%
help(list.count)
# Out:
# Help on method_descriptor:
#
# count(self, value, /)
#     Return number of occurrences of value.

# %%
string = ['*',' ','*','\n']

# %%
print(''.join(string) + ''.join(string))
# Out:
# * *
# * *
