# %%
from collections import Counter

# %%
s = 'Hello World'

# %%
s
# Out:
# 'Hello World'

# %%
lst = Counter(s)

# %%
type(lst)
# Out:
# collections.Counter

# %%
Counter(list(s))
# Out:
# Counter({'l': 3, 'o': 2, 'H': 1, 'e': 1, ' ': 1, 'W': 1, 'r': 1, 'd': 1})

# %%
list(s)
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']

# %%
s.replace(' ','')
# Out:
# 'HelloWorld'

# %%
r = list(s.replace(' ',''))[::-1]

# %%
s
# Out:
# 'Hello World'

# %%
sum([True,True])
# Out:
# 2
