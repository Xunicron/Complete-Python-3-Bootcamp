# %%
def my_funct(your_text):
    "prints your text"
    print(your_text)

my_funct('Hi')
# Out:
# Hi

# %%
def add_number(num1=0,num2=0):
    return num1+num2

addition = add_number(3,4)
addition
# Out:
# 7

# %%
add_number(3,5)
# Out:
# 8

# %%
add_number
# Out:
# <function __main__.add_number(num1, num2)>

# %%
def say_hello(name='no name'):
    print(f'Hello {name}')

# %%
say_hello('Hippie')
# Out:
# Hello Hippie

# %%
say_hello()
# Out:
# Hello no name

# %%
def print_result(a,b):
    print(a+b)

# %%
def return_result(a,b):
    return a+b

# %%
print_result(10,20)
# Out:
# 30

# %%
value = return_result(10,20)
value
# Out:
# 30

# %%
return_result('hi','low')
# Out:
# 'hilow'
