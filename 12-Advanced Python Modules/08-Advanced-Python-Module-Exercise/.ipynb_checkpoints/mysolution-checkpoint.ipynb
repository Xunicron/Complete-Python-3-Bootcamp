# %%
import shutil

# %%
pwd
# Out:
# '/Users/kyaw_ford/Documents/Python Learning/Complete-Python-3-Bootcamp/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/extracted_content'

# %%
import os

# %%
os.listdir()
# Out:
# ['Instructions.txt', 'Three', 'One', 'Two', 'Five', 'Four']

# %%
cur_dir = '/Users/kyaw_ford/Documents/Python Learning/Complete-Python-3-Bootcamp/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise'

# %%
shutil.unpack_archive('unzip_me_for_instructions.zip',cur_dir,'zip')

# %%
os.chdir('/Users/kyaw_ford/Documents/Python Learning/Complete-Python-3-Bootcamp/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise')

# %%
dir_list = os.listdir()

# %%
dir_list
# Out:
# ['07-Advanced-Modules-Exercise-Puzzle.ipynb',
#  '08-Advanced-Modules-Exercise-Solutions.ipynb',
#  'unzip_me_for_instructions.zip',
#  '.ipynb_checkpoints',
#  'mysolution.ipynb',
#  'extracted_content']

# %%
for folder , sub_folders , files in os.walk("extracted_content"):
    
    print("Currently looking at folder: "+ folder)
    print('\n')
    print("THE SUBFOLDERS ARE: ")
    for sub_fold in sub_folders:
        print("\t Subfolder: "+sub_fold )
    
    print('\n')
    
    print("THE FILES ARE: ")
    for f in files:
        print("\t File: "+f)
    print('\n')
    
    # Now look at subfolders
# Out:
# Currently looking at folder: extracted_content
#
#
# THE SUBFOLDERS ARE:
# 	 Subfolder: Three
# 	 Subfolder: One
# 	 Subfolder: Two
# 	 Subfolder: Five
# 	 Subfolder: Four
#
#
# THE FILES ARE:
# 	 File: Instructions.txt
#
#
# Currently looking at folder: extracted_content/Three
#
#
# THE SUBFOLDERS ARE:
#
#
# THE FILES ARE:
# 	 File: VSXFSTABZDY.txt
# 	 File: YDQFMWXOUMW.txt
# 	 File: YQBIUHSUEVW.txt
# 	 File: XAJMCPEWFNI.txt
# 	 File: ZXEZRQXZNPG.txt
# 	 File: ZKQJXAYKPVD.txt
# 	 File: XVMPVSVYKFR.txt
# 	 File: XHZPVUQTXIO.txt
# 	 File: YYIZGBTQHZP.txt
# 	 File: VCFJCGJFBIH.txt
# 	 File: VVHFVZUNLOO.txt
# 	 File: VVKGWLRMHLU.txt
# 	 File: XJCWENFFGHB.txt
# 	 File: XFHJOTNPEJG.txt
# 	 File: ZOWVXWPOGWP.txt
# 	 File: ZXIBJMPROKW.txt
# 	 File: VAQIJTDOFUJ.txt
# 	 File: YCESZHJDBXH.txt
# 	 File: YQRNCMNFFHW.txt
# 	 File: ZEZKKRBIZEB.txt
#
#
# Currently looking at folder: extracted_content/One
#
#
# THE SUBFOLDERS ARE:
#
#
# THE FILES ARE:
# 	 File: LFEATJAAYDC.txt
# ...

# %% [markdown]
# ## Solution

# %%
import os
import re

# list directory
os.listdir()

# get current directory 
cur_dir = os.getcwd()

# unzip puzzle folder
shutil.unpack_archive('unzip_me_for_instructions.zip',cur_dir,'zip')

# change dir to puzzle folder
os.chdir('/Users/kyaw_ford/Documents/Python Learning/Complete-Python-3-Bootcamp/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise')

# Get the current working directory and assign it to a variable
path = os.getcwd()

# iterate through each directory
dir_list = os.listdir()
print(dir_list, '\n')

for folder , sub_folders , files in os.walk("extracted_content"):
    
    print("Currently looking at folder: "+ folder)
    print('\n')
    print("THE SUBFOLDERS ARE: ")
    
    # iterate through each subfolder
    for sub_fold in sub_folders:
        print("\t Subfolder: "+sub_fold )
    print('\n')
    
    # iterate through each file
    print("THE FILES ARE: ")
    for f in files:
        print("\t File: "+f)

        # open file
        with open(f,'r') as file:
            contents = file.read()

        # search for a telephone number.
        #print(contents)


    print('\n')
# Out:
# ['07-Advanced-Modules-Exercise-Puzzle.ipynb', '08-Advanced-Modules-Exercise-Solutions.ipynb', 'unzip_me_for_instructions.zip', '.ipynb_checkpoints', 'mysolution.ipynb', 'extracted_content']
#
# Currently looking at folder: extracted_content
#
#
# THE SUBFOLDERS ARE:
# 	 Subfolder: Three
# 	 Subfolder: One
# 	 Subfolder: Two
# 	 Subfolder: Five
# 	 Subfolder: Four
#
#
# THE FILES ARE:
# 	 File: Instructions.txt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[69], line 40
#      37 print("\t File: "+f)
#      39 # open file
# ---> 40 with open(f,'r') as file:
#      41     contents = file.read()
#      43 # search for a telephone number.
#      44 #print(contents)
#
# File /Users/kyaw/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
# ...

# %%
pwd
# Out:
# '/Users/kyaw_ford/Documents/Python Learning/Complete-Python-3-Bootcamp/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise'
