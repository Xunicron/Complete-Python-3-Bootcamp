# %%
pwd
# Out:
# '/Users/kyaw_ford/Documents/Python Learning/Complete-Python-3-Bootcamp/12-Advanced Python Modules'

# %%
f = open('practice.txt','w+')

# %%
f.write('test')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/kyaw_ford/Documents/Python Learning/Complete-Python-3-Bootcamp/12-Advanced Python Modules'

# %%
os.listdir('/Users/kyaw_ford/')
# Out:
# ['Music',
#  '.condarc',
#  '.bitwarden-ssh-agent.sock',
#  '.DS_Store',
#  '.CFUserTextEncoding',
#  'Pictures',
#  'practice.txt',
#  '.zsh_history',
#  '.ipython',
#  'Desktop',
#  'Library',
#  '.oracle_jre_usage',
#  'Public',
#  '.dropbox',
#  '.anaconda',
#  'Movies',
#  'Applications',
#  'Dropbox',
#  '.Trash',
#  '.jupyter',
#  'Documents',
#  '.vscode',
#  'Downloads',
#  '.continuum',
#  '.gitconfig',
#  '.viminfo',
#  '.zsh_sessions',
#  '.conda']

# %%
import shutil

# %%
shutil.move('practice.txt','/Users/kyaw_ford/')
# Out:
# '/Users/kyaw_ford/practice.txt'

# %%
os.listdir('/Users/kyaw_ford/')
# Out:
# ['Music',
#  '.condarc',
#  '.bitwarden-ssh-agent.sock',
#  '.DS_Store',
#  '.CFUserTextEncoding',
#  'Pictures',
#  'practice.txt',
#  '.zsh_history',
#  '.ipython',
#  'Desktop',
#  'Library',
#  '.oracle_jre_usage',
#  'Public',
#  '.dropbox',
#  '.anaconda',
#  'Movies',
#  'Applications',
#  'Dropbox',
#  '.Trash',
#  '.jupyter',
#  'Documents',
#  '.vscode',
#  'Downloads',
#  '.continuum',
#  '.gitconfig',
#  '.viminfo',
#  '.zsh_sessions',
#  '.conda']

# %%
pip install send2trash
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['Example_Top_Level',
#  'Untitled1.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'Untitled.ipynb',
#  '00-Collections-Module.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '02-Datetime-Module.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '.ipynb_checkpoints',
#  '04-Python Debugger (pdb).ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb']

# %%
shutil.move('/Users/kyaw_ford/practice.txt', os.getcwd())
# Out:
# '/Users/kyaw_ford/Documents/Python Learning/Complete-Python-3-Bootcamp/12-Advanced Python Modules/practice.txt'

# %%
send2trash.send2trash('practice.txt')

# %%
os.getcwd()
# Out:
# '/Users/kyaw_ford/Documents/Python Learning/Complete-Python-3-Bootcamp/12-Advanced Python Modules'
