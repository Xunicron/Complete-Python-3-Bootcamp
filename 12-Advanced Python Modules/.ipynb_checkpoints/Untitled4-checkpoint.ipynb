# %%
x = [1,3,4]
y = 2
z = 3

result = y + z
print(result)
result2 = x+y
print(result2)
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       5 result = y + z
#       6 print(result)
# ----> 7 result2 = x+y
#       8 print(result2)
#
# TypeError: can only concatenate list (not "int") to list

# %%
x = [1,3,4]
y = 2
z = 3

# %%
import pdb

# %%
x = [1,3,4]
y = 2
z = 3

result_one = y+z

pdb.set_trace()

result_two = y+x
# Out:
# --Return--
# None
# > /var/folders/4g/h5429r057777b00dx30gpb_c0000gp/T/ipykernel_7509/1944962416.py(7)<module>()
#       5 result_one = y+z
#       6
# ----> 7 pdb.set_trace()
#       8
#       9 result_two = y+x
#
# ipdb> y
# 2
# ipdb> x
# [1, 3, 4]
# ipdb> z
# 3
# ipdb> result_one
# 5
# ipdb> result_two
# *** NameError: name 'result_two' is not defined
# ipdb> x=y
# ipdb> x+y
# 4
# ipdb> x+z
# 5
# ipdb> x=[1,3,4]
# ipdb> x+z
# *** TypeError: can only concatenate list (not "int") to list
# ipdb> q
