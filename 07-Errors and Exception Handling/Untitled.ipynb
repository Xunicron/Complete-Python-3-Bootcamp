# %%
def add(n1,n2):
    print(n1+n2)

# %%
add(10,20)
# Out:
# 30

# %%
number1 = 10

# %%
number2 = input("Number?: ")
# Out:
# Number?: 20

# %%
try:
    add(10,'20')
except:
    print("Something happened")
else:
    print("Fine")
finally:
    print("OK")
# Out:
# Something happened
# OK

# %%
try:
    f = open('testfile','r')
    f.write("Write a test line")
except TypeError:
    print("Type error")
except OSError:
    print("OS error")
finally:
    print("Always runs")
# Out:
# OS error
# Always runs
